# %% [markdown]
# <a href="https://colab.research.google.com/github/sdecho/python-data-visualization/blob/main/Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Package imports- if you are running this locally, you need to install the packages.
# Data handling
import pandas as pd #documentation page: https://pandas.pydata.org/docs/reference/index.html
import numpy as np #https://numpy.org/doc/stable/reference/index.html

# Plotting
import matplotlib.pyplot as plt #https://matplotlib.org/stable/plot_types/index.html
import seaborn as sns # https://seaborn.pydata.org/

# %%
# %pwd # showing your working folder
# Out:
# '/content'

# %%
# You can also set this for individual figures
# Make plots a little easier to read
sns.set_theme(style="whitegrid")

# Default figure size
plt.rcParams["figure.figsize"] = (7, 5)

# Default font size
plt.rcParams["font.size"] = 12

# %%
# Read our dataset into a pandas DataFrame
df = pd.read_csv("data.csv")

# Show the first 5 rows
df.head()
